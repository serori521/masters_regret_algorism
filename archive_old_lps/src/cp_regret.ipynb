# %%
using Pkg
Pkg.activate("..")
println("Julia version: ", VERSION)
# Out:
#   Activating project at `/workspaces/inulab_julia_devcontainer`
# Julia version: 1.11.2

# %%
# セル1: 環境セットアップとモジュール読み込み

# パス調整：
# devcontainerならプロジェクトルートを /workspaces/... とかにしてるはずなので
# そこから src/SetRegretCore.jl と src/RegretRTR.jl を読み込みます。
#
# 例:
# cd("/workspaces/inulab_julia_devcontainer/src")
# みたいなカレント調整を入れてもOK。
#
# ここでは相対パス "./src" としておくので、
# ノートブックをプロジェクトルートに置く想定。

push!(LOAD_PATH, "./src")

# 明示的に include して依存順にロード
include("./cp_extra.jl")
include("./cp_regret_replace.jl")

using .SetRegretCore
using .RegretRTR

println("Modules loaded:")
println("  SetRegretCore  ✅")
println("  RegretRTR      ✅")
# Out:
# LoadError: UndefVarError: `SetRegretCore` not defined in `Main.RegretRTR`
#
# Suggestion: check for spelling errors or missing imports.
#
# in expression starting at /workspaces/inulab_julia_devcontainer/src/cp_extra.jl:1
#
#
#
# Stacktrace:
#
#  [1] include(fname::String)
#
#    @ Main ./sysimg.jl:38
#
#  [2] top-level scope
#
#    @ /workspaces/inulab_julia_devcontainer/src/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sdnNjb2RlLXJlbW90ZQ==.jl:17
